# %%
# !pip install albumentations opencv-python numpy
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.11/dist-packages (1.4.20)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from albumentations) (2.10.5)
# Requirement already satisfied: albucore==0.0.19 in /usr/local/lib/python3.11/dist-packages (from albumentations) (0.0.19)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.11/dist-packages (from albumentations) (0.2.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.11/dist-packages (from albumentations) (4.10.0.84)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from albucore==0.0.19->albumentations) (3.11.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->albumentations) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.7.0->albumentations) (4.12.2)

# %%
import os
import cv2
import random
from albumentations import (
    Rotate, ShiftScaleRotate, RandomBrightnessContrast,
    Perspective, ColorJitter, Compose
)
from albumentations.core.composition import OneOf

# Define Paths
input_dir = "/content/drive/MyDrive/GAP DETECTION/lat"  # Update with your input image folder
output_dir = "/content/drive/MyDrive/GAP DETECTION/aug-imgs-190125"  # Update with your output folder

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Parameters
target_image_count = 1000
augmentations_per_image = 20

# Augmentation Pipeline
def get_augmentation_pipeline():
    return Compose(
        [
            OneOf([
                Rotate(limit=20, p=1.0),
                ShiftScaleRotate(shift_limit=0.02, scale_limit=0.2, rotate_limit=20, p=1.0),
                Perspective(scale=(0.02, 0.06), p=1.0),
            ], p=0.8),
            RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
            ColorJitter(hue=0.2, saturation=0.2, brightness=0.2, contrast=0.2, p=0.5),
        ]
    )

# Augment Dataset
def augment_dataset(input_dir, output_dir, target_image_count, augmentations_per_image):
    pipeline = get_augmentation_pipeline()

    # List all images in the input folder
    images = [f for f in os.listdir(input_dir) if f.endswith((".jpg", ".png"))]
    num_images = len(images)
    generated_count = 0

    for image_name in images:
        image_path = os.path.join(input_dir, image_name)

        # Load the image
        img = cv2.imread(image_path)

        for i in range(augmentations_per_image):
            augmented = pipeline(image=img)
            aug_img = augmented["image"]

            # Save augmented image
            aug_image_name = f"{os.path.splitext(image_name)[0]}_aug_{i + generated_count}.jpg"
            aug_image_path = os.path.join(output_dir, aug_image_name)
            cv2.imwrite(aug_image_path, aug_img)

            generated_count += 1

            # Stop augmentation if the target count is reached
            if generated_count >= target_image_count - num_images:
                break

        print(f"Completed augmentation for image: {image_name}")

# Run Augmentation
augment_dataset(input_dir, output_dir, target_image_count, augmentations_per_image)
# Out:
# Completed augmentation for image: ADANIENT_2024-02-26_13-10-46_png.rf.0162f2cfb2de6265a14a33f7f94934a6.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-28-42-PM_png.rf.2304bd9c94a180263d5a5c024cdb4953.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-26-44-PM_png.rf.2866c8e14c2efc457e68f92bd36172f5.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-26-44-PM_png.rf.40e99b396c3d135c6d81d5c356d5ec32.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-25-11-PM_png.rf.82d223584322ecee29ced75ec2b18776.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-25-57-PM_png.rf.faea5b45745123269ca790e16180bc23.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-25-57-PM_png.rf.1f2d7ee152a5c7f7913d37f592b4173e.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-25-57-PM_png.rf.45e78e1fe34f5988a50dee8e0402c158.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-26-44-PM_png.rf.7c7082af7a60531539e3c6101fbdb454.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-25-11-PM_png.rf.6e9b2bdbd6b60d2c83bf7aed831a0c17.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-24-50-PM_png.rf.f956fb2dae497f4046a5eebda0abe19e.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-25-11-PM_png.rf.cef7b36c48f1a8a6ae17ffc96de92f3d.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-20-31_png.rf.c71b95859cd2757e843e982847c84780.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-21-04_png.rf.cd3d7bba380dda0213acca5f52eab1db.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-21-04_png.rf.5ed0bc4e5601c86010354d97902b1644.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-20-31_png.rf.53925b4d201263de697442976d64da7b.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-21-04_png.rf.be765793c49defc82488f237e1f5bcfe.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-24-50-PM_png.rf.771bf758e105382a8bbe9211dfa8f5c7.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-22-11_png.rf.c8d379406b35d3d4ecc5eb2f45f7d232.jpg
# Completed augmentation for image: IDEA_2024-02-26_12-26-31_png.rf.fcb90f0ecffd45087f9803035a62552d.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-22-11_png.rf.b0d61cb4fe66b86c420b64d8e326b164.jpg
# Completed augmentation for image: IDEA_2024-02-26_12-26-31_png.rf.829293b692f74720a34bc7a152bfed08.jpg
# Completed augmentation for image: IDEA_2024-02-26_12-26-31_png.rf.2f49e5b0951154eddb696ae34c9af858.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-16-40_png.rf.df81749e790a55c57371eb97d0f877b0.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-20-08_png.rf.3a9c01eaf5a62b3b8609b2c2ad5315b4.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-20-08_png.rf.ef221855a12e6258d77e8117142f4879.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-20-31_png.rf.5f8c03d0ec7d27ebf0c8be83b32beb2c.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-22-11_png.rf.34966c0373c8f30f9cfd83edbbc5bf21.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-24-50-PM_png.rf.2feb9af686803aac723cf1226808165c.jpg
# Completed augmentation for image: IDEA_2024-02-26_12-26-59_png.rf.03b6a712779b91e5bcdf2fba1f59b8ea.jpg
# Completed augmentation for image: IDEA_2024-02-26_12-26-59_png.rf.260dc19afa963c04fbb165e755570c7d.jpg
# Completed augmentation for image: IDEA_2024-02-26_12-26-59_png.rf.449307e6d018a1c48a410b903c4169ca.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-20-08_png.rf.ae0c3875a19f796acc686693f76ad32a.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-16-40_png.rf.029651e7a71b776d4db9665b7cc9e5f0.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-15-53_png.rf.80d6f0b127023a58c4a41105935d509a.jpg
# Completed augmentation for image: GMRINFRA_2024-02-26_12-25-22_png.rf.d8b9e6f7ff24f29f1d2b1dc6a7cf5c70.jpg
# Completed augmentation for image: GMRINFRA_2024-02-26_12-25-22_png.rf.46e3787eae569b6b0dba05ae4f4d030c.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-16-40_png.rf.ad25a36a0d396117e7d0e21b9a73a02e.jpg
# Completed augmentation for image: GMRINFRA_2024-02-26_12-25-22_png.rf.83b563d87c095c123e8a650d0ce7bb79.jpg
# Completed augmentation for image: COFORGE_2024-02-26_12-23-19_png.rf.e8a0d8af31dde307c9d52c5c0c191249.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-15-53_png.rf.44f24527a6051891eb1e86624359425b.jpg
# Completed augmentation for image: HDFCBANK_2024-02-26_13-15-53_png.rf.061ab282d4abf6b8261ca96f9f429b61.jpg
# Completed augmentation for image: COFORGE_2024-02-26_12-23-19_png.rf.b2e2b8ad0f905a5a800bce58762dd485.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-10-46_png.rf.edf296123577f9de02461d651c76ef09.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-14-44_png.rf.1fad89eeafa8657a1101badef45d6da9.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-14-44_png.rf.af3258513d01578d371945982b39be48.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-14-44_png.rf.0e87fa84a960dc27d0da696091bc7d86.jpg
# Completed augmentation for image: COFORGE_2024-02-26_12-23-19_png.rf.85320110cfb800d77203e351e707a0d5.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-10-46_png.rf.90166e9be40ce8099ec89b610bc225a2.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-09-57_png.rf.be4c622749e5d71839d15fa447209735.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-09-57_png.rf.f46babb42fa4d2601515763ae38d3b89.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-45-43-PM_png.rf.8ec70ef535d475c1da9044103a5104c9.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-44-54-PM_png.rf.889f125d38023f985dc708d242a811e5.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-44-54-PM_png.rf.968cc3cdc8c035d39b023586d088c996.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-41-03-PM_png.rf.a1961613345f189ed9f3159d33f92ed6.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-36-20-PM_png.rf.ecf12759bf8aaafaa60825d40740aa59.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-41-03-PM_png.rf.b00bce41ed271345940ecf845fd48b30.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-42-02-PM_png.rf.2aeca53176a9dc12b380123ac65ed143.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-41-03-PM_png.rf.2848b819e3ee10b1d443e084cb265c13.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-42-02-PM_png.rf.334983d63ddddc9cbb2149fbe728f394.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-42-02-PM_png.rf.ec9808aab447f9b790cc3361d2cdaac9.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-33-03-PM_png.rf.0c5708c9cfc68388756421ba322086f3.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-32-23-PM_png.rf.ce3432e5ee9f6ba93fd637684a84574b.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-33-03-PM_png.rf.294cc499ec41ae6114dd14f92dde560d.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-35-40-PM_png.rf.2a287b3dd993298547cea69c3606017c.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-32-23-PM_png.rf.4486a8cbaf27093660130387d4a2a399.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-36-20-PM_png.rf.2fa3e8f8974086383ca0fffe5c4c38c6.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-36-20-PM_png.rf.bf090db0ba47b0d875cf23d24e077caf.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-35-40-PM_png.rf.66a59cb386638d777a48e97d8a687d14.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-44-54-PM_png.rf.f84d630715e5bc5afebe792ff9ea373b.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-35-40-PM_png.rf.36e6fc2421306475832388a3c7289f31.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-32-02-PM_png.rf.3ae07169f817df801d56ba90eff0f4eb.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-32-02-PM_png.rf.a1ff42767b7be6c4cd844d936a19ab64.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-33-03-PM_png.rf.46880365e1611d4610c6253902717459.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-32-23-PM_png.rf.5bf807e14772e5d1151074a04f31fee3.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-30-37-PM_png.rf.6667284dba238c68b21b22b8df02490f.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-30-06-PM_png.rf.f0a2698a8d2e5906554d6d87e2c8d7b0.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-30-37-PM_png.rf.c363ca553478e497041ecd3c4cedd86f.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-30-37-PM_png.rf.f890146c41b0ce3e600f003c3dd0d6f4.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-30-06-PM_png.rf.ec2e459fbcd3420d620f16b9b826be05.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-32-02-PM_png.rf.a2abfdb38c689c25d3b4459fa2e16c3e.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-28-42-PM_png.rf.711cd4f35d81fd2677bd9ba212a0d501.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-30-06-PM_png.rf.6858c48b67b6242011802a7bd85b49c2.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-28-42-PM_png.rf.b97c9190463a1a7d02ed5e5cefefe9e0.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-46-12-PM_png.rf.5c22119e881731f0b425e733d1aaaad4.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-09-33_png.rf.272289c7f102a2445d8ca7b29aab862f.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-09-57_png.rf.a1f7d11fa0006fc36ef47e88d3a1c7c5.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-45-43-PM_png.rf.e1e1b978aa5f0f996fbdb5b898f9a1b7.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-45-43-PM_png.rf.dd9d8f5929a5e6b99ad10c24887c84b0.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-00-57_png.rf.d9daac4bc3c296fe9b74fe26d856e671.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-09-33_png.rf.1979f98dc4924fd4a0356c0e96d37ad2.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-00-57_png.rf.534ade2912fbac84ea64cfdaca1250cc.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-46-12-PM_png.rf.e5e793e1d34f8ef02932fccb474d1ab5.jpg
# Completed augmentation for image: Screenshot-2024-02-26-at-12-46-12-PM_png.rf.7464df5459ce4b00a7ab51ebf51c1985.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-00-57_png.rf.b7efa539d50be84025156f8feeab174b.jpg
# Completed augmentation for image: ADANIENT_2024-02-26_13-09-33_png.rf.5169efd37f6e4bf13ddee860e1313d51.jpg
